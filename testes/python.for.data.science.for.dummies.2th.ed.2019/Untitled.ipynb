# %%
import matplotlib.image as img
import matplotlib.pyplot as plt 
# %matplotlib inline

image = img.imread('Colorblk.jpg')
print(image.shape)
print(image.size)
plt.imshow(image)
plt.show()
# Out:
# (100, 100, 3)
# 30000
